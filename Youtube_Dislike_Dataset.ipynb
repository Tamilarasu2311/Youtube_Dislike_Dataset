# %% [markdown]
# # 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

dt=pd.read_csv('youtube_dislike_dataset.csv')
dt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
dt.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
dt.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# # 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# Inference on data types:
# There are totally 12 columns in the given data.
# Out of that 4 columns are in integer data type.
# Remaining 8 columns are in object data type.

# %%
dt.shape
# Out:
# (37422, 12)

# %% [markdown]
# Inference on shape:
# From the shape, it is inferred that the given data has 37422 rows and 12 columns

# %% [markdown]
# # 3. Check for the Percentage of the missing values and drop or impute them.

# %%
missing_values_percentage= dt.isnull().sum()*100/len(dt)
missing_values_percentage
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
dt=dt.dropna()
dt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# # 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
#statistical summary of both numerical columns
dt.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %% [markdown]
# Inference on statistical summary of numerical columns:
# It is inferred with the basic knowledge about youtube, view_count remains on top by comparing with likes, dislikes and comment_count. By this statement it is concluded that the given data is matches with the real time statistics.

# %%
#statistical summary of categorical columns
dt.describe(include='object')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37264  37264       37264
# unique                36617  28705       35479
# top     2020-10-16 04:00:10
# freq                      6   3808         587
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %% [markdown]
# Inference on statistical summary of categorical columns: It is inferred that the columns namely channel_id, channel_title are having less number of unique values comparing to other categorical columns. Because the values in channel_title are name of the youtube channels so they are less in number.

# %% [markdown]
# # 5. Convert datatype of column published_at from object to pandas datetime.

# %%
dt.Date=pd.to_datetime(dt.published_at)
dt.Date
# Out:
# C:\Users\rtata\AppData\Local\Temp\ipykernel_8528\283860775.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dt.Date=pd.to_datetime(dt.published_at)
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37264, dtype: datetime64[ns]

# %% [markdown]
# # 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
dt.published_month=dt.Date.dt.month
dt.published_month
# Out:
# C:\Users\rtata\AppData\Local\Temp\ipykernel_8528\45355724.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dt.published_month=dt.Date.dt.month
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_at, Length: 37264, dtype: int64

# %% [markdown]
# # 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....

# %%
dt['month_name']=dt.published_month.replace({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})
dt['month_name']
# Out:
# C:\Users\rtata\AppData\Local\Temp\ipykernel_8528\2657106494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt['month_name']=dt.published_month.replace({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})
# 0        Jul
# 1        Jun
# 2        Sep
# 3        Mar
# 4        Dec
#         ...
# 37417    Feb
# 37418    Jan
# 37419    Jun
# 37420    Oct
# 37421    May
# Name: month_name, Length: 37264, dtype: object

# %% [markdown]
# # 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
dt.groupby('month_name')['title'].count().sort_values(ascending=False)
# Out:
# month_name
# Oct    4976
# Sep    4854
# Nov    4821
# Aug    4250
# Dec    3063
# Jul    2331
# Jun    2305
# Mar    2248
# Feb    2125
# Apr    2119
# Jan    2099
# May    2073
# Name: title, dtype: int64

# %% [markdown]
# # 9. Find the count of unique video_id, channel_id and channel_title.

# %%
dt['video_id'].nunique()
# Out:
# 37264

# %%
dt['channel_id'].nunique()
# Out:
# 10891

# %%
dt['channel_title'].nunique()
# Out:
# 10813

# %% [markdown]
# # 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
dt.groupby('channel_title')['title'].count().sort_values(ascending=False).head(10)
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: title, dtype: int64

# %%
dt.groupby('channel_title')['title'].count().sort_values(ascending=False).tail(10)
# Out:
# channel_title
# Karikku Tuned      1
# Karen Bustillos    1
# Karen Aslanyan     1
# Karchez            1
# Karate Combat      1
# Kaptain Kuba       1
# Kanye West         1
# Kannur kitchen     1
# Kannada Cinema     1
# zoom               1
# Name: title, dtype: int64

# %% [markdown]
# # 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
#dt.groupby('title')['likes'].sum().sort_values(ascending=False).head(1)
dt['title'][dt['likes']==dt['likes'].max()]
# Out:
# 26143    BTS () 'Dynamite' Official MV
# Name: title, dtype: object

# %%
#dt.groupby('title')['likes'].sum().sort_values(ascending=False).tail(1)
dt['title'][dt['likes']==dt['likes'].min()]
# Out:
# 23855    Leading the Charge | Circle K
# Name: title, dtype: object

# %% [markdown]
# Inference of analyzing likes of the videos: It is inferred that "BTS () 'Dynamite' Official MV" video has most number of likes and also inferrred that "Leading the Charge | Circle K" video has very less number of likes.

# %% [markdown]
# # 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
#dt.groupby('title')['dislikes'].max().sort_values(ascending=False).head(1)
dt['title'][dt['dislikes']==dt['dislikes'].max()]
# Out:
# 13591    Cuties | Official Trailer | Netflix
# Name: title, dtype: object

# %%
#dt.groupby('title')['dislikes'].min().sort_values().head(1)
dt['title'][dt['dislikes']==dt['dislikes'].min()]
# Out:
# 29482    Tims For Good: A Taste Of The Familiar
# Name: title, dtype: object

# %% [markdown]
# Inference of analyzing likes of the videos: It is inferred that "Cuties | Official Trailer | Netflix" video has most number of dislikes and also inferrred that "Tims For Good: A Taste Of The Familiar" | E! News" video has very less number of dislikes.

# %% [markdown]
# # 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
sns.heatmap(dt.corr(),annot=True)
plt.show()
# Out:
# C:\Users\rtata\AppData\Local\Temp\ipykernel_8528\1676872686.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dt.corr(),annot=True)

# %% [markdown]
# # 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
dt[dt['month_name']=='Jan']
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title         published_at  \
# ...

# %%
dt['video_id'][dt['month_name']=='Jan'].count()
# Out:
# 2099
